# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open('C:/Users/MY LENOVO/Desktop/butterfly.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=672x378 at 0x221DB49FEF0>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arr = np.asarray(img)

# %%
type(img_arr)
# Out:
# numpy.ndarray

# %%
img_arr.shape
# Out:
# (378, 672, 3)

# %%
plt.imshow(img_arr)

# %%
img2 = img_arr.copy()

# %%
plt.imshow(img2)

# %%
# 0 - Red, 1- Green, 2- Blue
img2[:,:,0]
# Out:
# array([[228, 228, 228, ..., 228, 228, 228],
#        [228, 228, 228, ..., 228, 228, 228],
#        [228, 228, 228, ..., 228, 228, 228],
#        ...,
#        [228, 228, 228, ..., 228, 228, 228],
#        [228, 228, 228, ..., 228, 228, 228],
#        [228, 228, 228, ..., 228, 228, 228]], dtype=uint8)

# %%
plt.imshow(img2[:,:,0])

# %%
plt.imshow(img2[:,:,0], cmap='gray')

# %%
plt.imshow(img2[:,:,1], cmap='gray')

# %%
plt.imshow(img2[:,:,2], cmap='gray')

# %%
img2[:,:,2].shape
# Out:
# (378, 672)

# %%
img2[:,:,1] = 0
img2[:,:,2] = 0

# %%
plt.imshow(img2)

# %%
img2 = img_arr.copy()
img2[:,:,0] = 0
img2[:,:,2] = 0

# %%
plt.imshow(img2)

# %%
img2 = img_arr.copy()
img2[:,:,0] = 0
img2[:,:,1] = 0

# %%
plt.imshow(img2)
